# %% [markdown]
# <a href="https://colab.research.google.com/github/pedroheriquesartoriocanalrocha-star/INTMI2025/blob/main/ALP_Pedro_Henrique.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Algoritimo e lógica de programação

# %% [markdown]
# ##Variáveis e Operadores

# %%
x = 5   #Isso é uma varialvel
print(x)
# Out:
# 5

# %% [markdown]
# ##Operadores
#
# Adição +
#
# Subtração -
#
# Divisão /
#
# Multiplicação *
#
# Resto da Divisão %
#
# Divisão Inteira //
#
# Exponenciação **

# %%
numero1 = 10
numero2 = 5

print("A soma é igual a: " , numero1 + numero2)
print("A subtração é igual a: " , numero1 - numero2)
print("A Divisão é igual a: " , numero1 / numero2)
print("A Multipilacação é igual a: " , numero1 * numero2)
print("A Resto da divisão é igual a: " , numero1 % numero2)
print("A Divisão inteira é igual a: " , numero1 // numero2)
print("A Exponenciação é igual a: " , numero1 ** numero2)
# Out:
# A soma é igual a:  15
# A subtração é igual a:  5
# A Divisão é igual a:  2.0
# A Multipilacação é igual a:  50
# A Resto da divisão é igual a:  0
# A Divisão inteira é igual a:  2
# A Exponenciação é igual a:  100000

# %%
idade = input("Digite a sua idade: ")
# Out:
# Digite a sua idade: 16

# %% [markdown]
# ##Tipos de dados
# int - para números inteiros (1 , 2, 3)
#
# str - para palavras e texto (palavra)
#
# float - para números com virgula (1.5 , 2.3 )
#
# bool - para binários, verdadeiro ou falso (True, False)

# %%
altura = float(input("Digite sua altura: "))
peso = float(input("Digite seu peso: "))

imc = peso / (altura * altura)
print("Seu imc é:", imc)
# Out:
# Digite sua altura: 1.75
# Digite seu peso: 78
# Seu imc é: 25.46938775510204

# %% [markdown]
# ##Estrutura Condicional
#
# if - se
#
# elif - senão se
#
# else - senão

# %%
nota = float(input("Digite a sua nota: "))
if (nota>= 7):
  print("Aprovado")
elif (nota>= 5):
  print("Recuperação")
else:
   print("Reprovado")
# Out:
# Digite a sua nota: 60
# Aprovado

# %% [markdown]
# Cire um algoritimo que leia a sua idade dependendo da idade as frases na tela:
#
# até 12 anos - Você é uma Criança!
#
# 13 - 18 - Você é Adolecente!
#
# 19 - 60 - Você é Adulto!
#
# acima de 60 - Você é Idoso

# %%
idade = float(input("Digite sua idade:"))
if(idade<=12):
  print("Você é Criança")
elif (idade >= 13 and idade <= 18):
  print("Você é Adolecente")
elif(idade >= 19 and idade <= 60):
   print("Você é Adulto")
else:
  print("Idoso")
# Out:
# Digite sua idade:16
# Você é Adolecente

# %% [markdown]
# Crie um algoritimo que receba 2 numeros e uma escolha que mostre o seguinte menu:
# Selecione o sinal
# 1- Adição
# 2- Subtração
# 3 - Multipiplicação
# 4 - Divisão
# Caso não escolha um numero válido apareça na tela: Opção invalida!
# se escolher 1 some os 2 numeros e mostre o resultado
# se escolher 2 subtraia os 2 numeros e mostre o resultado
# e assim com as outras opções
